# %% [markdown]
# # Data Wrangling with MongoDB
# ## OpenStreetMap Project
#
# The map area is the Triangle region of central North Carolina.  This area encompasses the three major cities of Raleigh, Durham and Chapel Hill and is home to technology hub Research Triangle Park.
#
# I downloaded the data from [Mapzen](https://mapzen.com/data/metro-extracts) as a 465MB(uncompressed) OSM file.
#
# ![Triangle area - NC](Raleigh_map.png)
#
# Map references:
# * http://gmaps-samples.googlecode.com/svn/trunk/fusiontables/rectangle_example.html
#
# * http://gis.stackexchange.com/questions/29523/is-there-a-website-that-will-let-me-see-add-markers-and-bounding-boxes-on-top-of
#
# ___

# %%
import xml.etree.cElementTree as ET
import re
from collections import defaultdict, Counter

import codecs
import json
from pymongo import MongoClient

# %%
map_file = 'raleigh_north-carolina.osm'

# %% [markdown]
# ### Definitions
#
# * **Node** - A node represents a specific point on the earth's surface defined by its latitude and longitude.  Each node comprises at least an id number and a pair of coordinates.
# <font color=orangeRed>Can I verify this in the dataset?</font>
# * **Way** - A way defines <u>linear</u> features and area boundaries.  A way is an ordered list of between 2 and 2,000 nodes that define a polyline.  Ways are used to represent features such as rivers and roads.
# * **Relations** - A relation is a multi-purpose data structure that documents a relationship between two or more data elements (nodes, ways and/or other relatations).  The relation's meaning is defined by its tags.  Typically the relation will have a 'type' tag. The relation's other tags need to be interpreted in light of the type tag.
#
# All of the above can have one or more associated *tags* which describe the meaning of a particular element.
#
# Reference: http://wiki.openstreetmap.org/wiki/Elements

# %% [markdown]
# ### Create a dictionary of elements
#
# SAX is Simple API for XML.  It's an event-driven mechanism for reading data from an XML document without having to read the entire DOM tree into memory.
#
# Goal: use iterative parsing to process the map file and figure out what and how many elements there are.  Create a dictionary with the element name as the key and the number of times this element is encountered as the value.

# %% [markdown]
# ###### From Lesson 6 - iterative parsing

# %%
def count_tags(filename):
    dict_x = {}
    for _, elem in ET.iterparse(filename):
        #resource: http://stackoverflow.com/questions/473099/check-if-a-given-key-already-exists-in-a-dictionary-and-increment-it
        dict_x[elem.tag] = dict_x.get(elem.tag,0) + 1
    return dict_x

# %%
elements = count_tags(map_file)
elements
# Out:
# {'bounds': 1,
#  'member': 7947,
#  'nd': 2529113,
#  'node': 2252660,
#  'osm': 1,
#  'relation': 797,
#  'tag': 827245,
#  'way': 224066}

# %% [markdown]
# ##### From Lesson 6 - tag types

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        k = element.attrib['k']
        if (lower.search(k)):
            keys['lower'] += 1
        elif (lower_colon.search(k)):
            keys['lower_colon'] += 1
        elif (problemchars.search(k)):
            keys['problemchars'] += 1  
            print (k)
        else:
            keys['other'] += 1
    return keys

def process_keys(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
keys = process_keys(map_file)
keys
# Out:
# chair lift
# {'lower': 509634, 'lower_colon': 273216, 'other': 44394, 'problemchars': 1}

# %% [markdown]
# *Note*: There is one key that contains problem characters: 'chair lift'
# Apparently keys are not supposed to include spaces

# %% [markdown]
# ##### From lesson 6 - exploring users

# %%
def get_user(element):
    return element.attrib['uid']

def process_users(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if 'uid' in element.attrib:
            users.add(get_user(element))
    return users

# %%
users = process_users(map_file)
len(users)
# Out:
# 730

# %% [markdown]
# ### Data auditing

# %% [markdown]
# ##### Audit street type

# %%
#Note: \b means match at "word boundary", ie. match full words only
#      \S+ means match one or more of anything *except* a space character
#      \.? means match zero or more period characters
#      $ means perform this match from the end of the string
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons",
           "Circle","Extension","Fork","Highway","Terrace", "Way"]

# UPDATE THIS VARIABLE
street_type_mapping = { "St": "Street",
            "St.": "Street",
            "Rd." : "Road",
            "Ave" : "Avenue",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "CIrcle": "Circle",
            "Cir": "Circle",
            "Ct" : "Court",
            "Dr" : "Drive",
           "Ext" : "Extension",
           "Ln" : "Lane",
           "Loop": "Loop",
           "Pkwy": "Parkway",
           "Pky": "Parkway",
           "Pl": "Place",
           "PI": "Place",
           "Rd": "Road",
           "Rd.": "Road",
           "ST": "Street",
           "St": "Street",
           "St,": "Street"
            }
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            
def is_street_name(elem):
    return (elem.attrib['k'] == 'addr:street')

def audit_streets(osmfile):
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osmfile, events=('start',)):
        if elem.tag == 'node' or elem.tag == 'way':
            for tag in elem.iter('tag'):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    return street_types

def update_street_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        #Use the replacement from the mapping if it exists.
        replacement = mapping.get(m.group(),0)
        if replacement:
            name = street_type_re.sub(replacement, name) 
    return name

# %% [markdown]
# ##### Audit street direction
#
# Want to identify streets that have an abbreviated directional component like: N, S, E, W at the beginning of the string.

# %%
street_direction = defaultdict(set)
street_direction_re = re.compile(r'^[S W|SW|S E|SE|N W|NW|N E|NE|N|E|W|S]\.?\s+', re.IGNORECASE)
# '(\s+[S W|SW|S E|SE|N W|NW|N E|NE|N|E|W|S]\.?$)|
#street_direction_re = re.compile(r'(\s+[West|S W|SW|S E|SE|N W|NW|N E|NE|N|E|W|S]\.?$)|(^[S W|SW|S E|SE|N W|NW|N E|NE|N|E|W|S]\.?\s+)')

for event, elem in ET.iterparse(map_file, events=('start',)):
        if elem.tag == 'node' or elem.tag == 'way':
            for tag in elem.iter('tag'):
                if is_street_name(tag):
                    street_name = tag.attrib['v']
                    m = street_direction_re.search(street_name)
                    if m:
                        direction_type = m.group()
                        street_direction[direction_type].add(street_name)

# %%
street_direction_mapping = {"E.": "East ",
                           "E": "East ",
                           "W": "West ",
                           "W.": "West ",
                           "S": "South ",
                           "S.": "South ",
                           "N": "North ",
                           "N.": "North "}


for value in street_direction.values():
    for street in value:
        print (street)
        m = street_direction_re.search(street)
        if m:
            sd = m.group()
            replacement = street_direction_mapping.get(sd.strip(),0)
            if replacement:
                street = street_direction_re.sub(replacement,street)
                print("   ==>",street)
# Out:
# E. Winmore Ave
#    ==> East Winmore Ave
# W Chapel Hill Street
#    ==> West Chapel Hill Street
# W EDENTON ST
#    ==> West EDENTON ST
# W Rosemary St.
#    ==> West Rosemary St.
# W Franklin St
#    ==> West Franklin St
# W. Franklin St.
#    ==> West Franklin St.
# W. Pettigrew St.
#    ==> West Pettigrew St.
# S Wilmington Street
#    ==> South Wilmington Street
# S Boylan Ave
#    ==> South Boylan Ave
# N Duke St Suite
#    ==> North Duke St Suite
# N Roxboro Rd
#    ==> North Roxboro Rd
# N Fordham Blvd.
#    ==> North Fordham Blvd.
# N Harrison Avenue
#    ==> North Harrison Avenue
# E Cabarrus Street
#    ==> East Cabarrus Street
# E Cameron Avenue
#    ==> East Cameron Avenue
# E Franklin Street
#    ==> East Franklin Street
# E Rosemary St.
#    ==> East Rosemary St.
# S. Boylan Ave
#    ==> South Boylan Ave

# %% [markdown]
# ##### From lesson 6 - improving street names

# %%
st_types = audit_streets(map_file)
for st_type, ways in st_types.items():
    for name in ways:
        better_name = update_street_name(name,street_type_mapping)
        if name != better_name:
            print (name,'=>', better_name)
# Out:
# defaultdict(set,
#             {'100': {'100'},
#              '1000': {'Six Forks Road #1000'},
#              '17': {'US Highway 17'},
#              '206': {'Barrett Dr Suite 206'},
#              '501': {'US 15;US 501'},
#              '54': {'Highway 54',
#               'State Highway 54',
#               'West Highway 54',
#               'West NC Highway 54'},
#              '55': {'Highway 55', 'NC Highway 55', 'US 55'},
#              '70': {'US 70'},
#              '751': {'NC Highway 751'},
#              'Ave': {'Atlantic Ave',
#               'E. Winmore Ave',
#               'East Winmore Ave',
#               'Fernway Ave',
#               'Glenwood Ave',
#               'Mountford Ave',
#               'S Boylan Ave',
#               'S. Boylan Ave'},
#              'Blvd': {'Airport Blvd',
#               'Capital Blvd',
#               'Martin Luther King Jr Blvd',
#               'Martin Luther King Jr. Blvd',
#               'Martin Luther King Junior Blvd',
#               'Southpoint Autopark Blvd',
#               'Witherspoon Blvd'},
#              'Blvd.': {'Durham-Chapel Hill Blvd.',
#               'N Fordham Blvd.',
#               'Southpoint Auto Park Blvd.'},
#              'Bypass': {'Highway 54 Bypass', 'US 15 501 Bypass'},
#              'CIrcle': {'Meadowmont Village CIrcle'},
#              'Chatham': {'East Chatham'},
#              'Cir': {'Braddock Cir', 'Daybrook Cir'},
#              'Crescent': {'West Acres Crescent'},
#              'Crossing': {'Oldham Forest Crossing'},
#              'Ct': {'Ashley Springs Ct',
#               'Bevel Ct',
#               'Braidwood Ct',
#               'Gulf Ct'},
#              'Dr': {'Allister Dr',
#               'Calabria Dr',
#               'Crab Orchard Dr',
#               'Detrick Dr',
#               'Fig Vine Dr',
#               'Gold Star Dr',
#               'Sablewood Dr',
#               'Stinson Dr',
#               'Triangle Plantation Dr',
#               'University Dr',
#               'Waterford Lake Dr',
#               'Westgate Dr'},
#              'Driver': {'Garrett Driver'},
#              'East': {'US Highway 70 East'},
#              'Ext': {'New Hope Commons Boulevard Ext', 'Pritchard Avenue Ext'},
#              'Grove': {'Newton Grove'},
#              'Hill': {'Chapel Hill'},
#              'Hills': {'The Circle at North Hills'},
#              'LaurelcherryStreet': {'LaurelcherryStreet'},
#              'Ln': {'Springerly Ln', 'Sunbow Falls Ln'},
#              'Loop': {'Amiable Loop', 'Farrow Glen Loop'},
#              'PI': {'Alexander Promenade PI'},
#              'Pkwy': {'McCrimmon Pkwy', 'Skyland Ridge Pkwy'},
#              'Pky': {'Brier Creek Pky', 'brier Creek Pky'},
#              'Pl': {'Balaji Pl'},
#              'Plaza': {'City Hall Plaza',
#               'Exchange Plaza',
#               'Park Forty Plaza'},
#              'Point': {'Rocky Point'},
#              'Practice': {'Triangle Family Practice'},
#              'Rd': {'Blue Ridge Rd',
#               'Buck Jones Rd',
#               'Chapel Hill Rd',
#               'Creedmoor Rd',
#               'N Roxboro Rd',
#               'Six Forks Rd'},
#              'Rd.': {'Bayleaf Church Rd.'},
#              'Run': {'Deep Gap Run', 'Morgans Corner Run'},
#              'ST': {'W EDENTON ST'},
#              'St': {'9th St',
#               'Hillsborough St',
#               'Holloway St',
#               'Kinsey St',
#               'Main at North Hills St',
#               'Tucker St',
#               'W Franklin St'},
#              'St,': {'Morris St,'},
#              'St.': {'E Rosemary St.',
#               'East Corcoran St.',
#               'East Franklin St.',
#               'W Rosemary St.',
#               'W. Franklin St.',
#               'W. Pettigrew St.',
#               'West Rosemary St.'},
#              'Suite': {'N Duke St Suite'},
#              'West': {'Columbia Place West',
#               'Highway 54 West',
#               'Highway 55 West',
#               'Highway West',
#               'NC Highway 55 West'}})

# %% [markdown]
# ##### Audit is_in
#
# Was curious about this field, but after review am still not clear on what it's for.

# %%
is_in = {}
for event, elem in ET.iterparse(map_file, events=('start',)):
    if elem.tag == 'node' or elem.tag == 'way':
        for tag in elem.iter('tag'):
            if tag.attrib['k'] == 'is_in':
                value = tag.attrib['v']
                is_in[value] = is_in.get(value,0) + 1
is_in
# Out:
# {'Chatham,North Carolina,N.C.,NC,USA': 3,
#  'Duke University': 47,
#  'Durham,North Carolina,N.C.,NC,USA': 47,
#  'Ellerbee Creek Watershed Association': 1,
#  'North Carolina School of Science and Math': 13,
#  'North Carolina,N.C.,NC,USA': 2,
#  'Orange,North Carolina,N.C.,NC,USA': 79,
#  'Pearsontown Elementary School': 1,
#  'Raleigh, NC': 2,
#  'Southwest Elementary School': 1,
#  'US': 1,
#  'Wake,North Carolina,N.C.,NC,USA': 26}

# %% [markdown]
# ##### Audit locations

# %%
location = defaultdict(set)
for event, elem in ET.iterparse(map_file, events=('start',)):
    if elem.tag == 'node' or elem.tag == 'way':
        name = is_in = ''
        for tag in elem.iter('tag'):
            if tag.attrib['k'] == 'name':
                name = tag.attrib['v']
            if tag.attrib['k'] == 'is_in':
                is_in = tag.attrib['v']
        location[is_in].add(name)
location
# Out:
# defaultdict(set,
#             {'': {'',
#               'Stonecliff Drive',
#               'Airport Drive',
#               'Old Forge Circle',
#               'East Martin Street',
#               'Berryhill Drive',
#               'Split Stone Lane',
#               'Carpenter Fire Station Rd',
#               'New Bern Ridge Drive',
#               'Rambeau Circle',
#               'Ridgehaven Townhomes',
#               'Brooklyn Street',
#               'Braddock Circle',
#               'River Pine Dr',
#               'Bashford Crest Lane',
#               'Fleming Drive',
#               'Rosewood Court',
#               'Becton Residence Hall',
#               'Cornell Street',
#               'Wal-Mart: Store 1751',
#               'Bedford Avenue',
#               'Stokesbury Court',
#               'Glendower Road',
#               'South Knightsbridge Road',
#               'Hogan Woods Circle',
#               'Summerwood Townhomes',
#               'Myers Park Drive',
#               'Kilgore Avenue',
#               'SAS Building Gn',
#               'Raney Ct',
#               'Ricon Place',
#               'Dry Creek Court',
#               'Tri-Star Mobil',
#               'Page Point Circle',
#               'Mcbride Drive',
#               'South Atley Lane',
#               'PNC Plaza',
#               'PharmaSys, Inc.',
#               'Omega Sports',
#               'Priestly Creek',
#               'Fisher Street',
#               'Tilford Lane',
#               'Gordon Street',
#               'Spring Valley Drive',
#               'Green Level',
#               'Venture IV',
#               'Tucker Street',
#               'Moorfoote Court',
#               'Bearcat Way',
#               'East Forest Drive',
#               'Tomkins Loop',
#               'Chalmette Court',
#               'Parkwood School',
#               'Infinity Lane',
#               'William Peace University',
#               'Hycliff Road',
#               'Red Trail',
#               'Creedmoor Crossings',
#               'Greystone Park Drive',
#               'Supreme Drive',
#               'Brickettwood Apartments',
#               'Global Cup',
#               'Flagstone Court',
#               'Slateworth Drive',
#               'Aesthetic Oral Health, Peter A. Tzendzalian, DDS',
#               'King Charles Lane',
#               "Parson's Chase",
#               'East Bayberry Court',
#               'Telluride Trail',
#               'Heck Andrews Way',
#               'Sweet Magnolia Place',
#               'George Pup Williams Drive',
#               'Westmouth Bay Court',
#               'Clarksburg Place',
#               'Maderia Court',
#               'Shurling Place',
#               'Cary Heights',
#               'Parkscene Lane',
#               'Temple Street',
#               'Moffit',
#               'Magellan Charter School',
#               'Clark Branch',
#               'Barbary Street',
#               'Helen Y. Stough Elementary School',
#               'West Raleigh Presbyterian Church',
#               '5 Alley',
#               'Sorrell Street',
#               'Taproot Lane',
#               'Mossbank Road',
#               'Stalling Evans Sports Medicine Centre',
#               'Arrow Wood Bend',
#               'Mourning Dove Road',
#               'Providence Ridge Road',
#               'Derby Drive',
#               'Canal Street',
#               'Birnham Lane',
#               'Bike Rack at Grinnells',
#               'Springmoor Court',
#               'Misty Woods Circle',
#               'Estes Court',
#               'Cool Pond Road',
#               'The Hamptons at Umstead',
#               'Ashton Glen Road',
#               'Quid Court',
#               'Budgetel',
#               'Greater Saint Paul Missionary Baptist Church',
#               'Ancient Oak Court',
#               'Firebirds Wood Fired Grill',
#               'Cedar Falls Drive',
#               'Cary Greenhouse',
#               'The Townes at Crabtree',
#               'West Chatham Street',
#               'Imperial Center Greenway',
#               'Callahan Circle',
#               'Porter Place',
#               'North King Charles Road',
#               'Hartford Court',
#               'Laurel Branch Drive',
#               'Masterwood Way',
#               'Mechanics and Farmers Bank',
#               'Zinfandel Place',
#               'Hillside Court',
#               'Jarman Drive',
#               'Hobgood Architects',
#               'Coronado Lane',
#               'Tutti Frutti',
#               'Ottawa Avenue',
#               'Glen Eden Pilot Park',
#               'Creative Music Studios',
#               'Marry Scroggs Elementary School',
#               'Ogburn Court',
#               'Evangelical Missionary Church',
#               'Fawn Lake Drive',
#               'Beamon Street',
#               'Jack',
#               'Courtland Drive',
#               'Wicklow Place',
#               'Imaginary Way',
#               'Van Page Boulevard',
#               'Build Upon A Rock Deliverance Ministry',
#               'White Pine Court',
#               'Sugar Hill Place',
#               'Mark K. Spano',
#               'Kingsboro',
#               'Governess Lane',
#               'Community Baptist Church',
#               'Sunlit Lane',
#               'Edmontonia',
#               'cimos',
#               'Research Drive',
#               'Greens Hollow Lane',
#               'Olde Raleigh Villas Townhomes',
#               'Cary Arts Center',
#               'Vickers Avenue',
#               '210 Alexander',
#               'Starmount',
#               'Rockcastle Drive',
#               'Inona Place',
#               'House Undergraduate Library',
#               'Esterbrook Court',
#               'Wynalda Way',
#               'Halpen Drive',
#               'Sun Tan City',
#               'Dunnington Circle',
#               'E',
#               'Mason Farm',
#               "Dillard's",
#               'Hubbard Drive',
#               'Cumberland Cove Apartments',
#               'Country Club Villa',
#               'Hereford Road',
#               'Plumas Dr',
#               'West Duke Building Bike Rack',
#               'Wyndham',
#               'Central Park Lane',
#               'Formosa Avenue',
#               'Abbey Road Tavern & Grill',
#               'Deer Ridge Drive',
#               "Governor's Row",
#               'Nowell Creek Court',
#               'Collins Building',
#               'Eliot Place',
#               'Cary Tennis Park',
#               'Kilmory Drive',
#               'Polbida Drive',
#               'Henrico Lane',
#               'Iris Lane',
#               'Royal Anne Lane',
#               'Old Apex Road',
#               'Pettys Lake Dam',
#               'Pierce Street',
#               'Maldon Drive',
#               'Willow Cry Lane',
#               'Joyner House',
#               'Midtown Green',
#               'Cotton Place',
#               'West Gerrell Court',
#               'Octavia Court',
#               'Grovechase Lane',
#               'Leonidas Court',
#               'Lasky Court',
#               'Driftwood Estates',
#               'Wood Hall Bike Rack 3',
#               'Joseph Johnston Court',
#               'Spruce Pine Trail',
#               'Geyer Court',
#               'Rosetta Drive',
#               "Big Ed's City Market Restaurant",
#               'Parchment Trail',
#               'Flowers Drive',
#               'Stedman Drive',
#               'Debra Drive',
#               'Sun Hill Lane',
#               'Wood Chapel Lane',
#               'Overland Trail',
#               'Kadhai The Indian Wok',
#               'Bright Angel Drive',
#               'Landings at Pine Creek',
#               'Bond Park Boathouse',
#               'Powell Street',
#               'Stone Mountain Rd; Stone Mountain Road',
#               'Smith Avenue',
#               'Vintage Church',
#               'Barbecue',
#               'Chivalry Ct',
#               'Morning Edge Drive',
#               'Kipos Greek Taverna',
#               'Jubilee Christian Church',
#               'Troodon',
#               'Restland Memorial Gardens',
#               'McGregor Drive',
#               'Pineview Drive',
#               'Tar Heel Coffee',
#               'Serena Place',
#               'Lakestone Place',
#               'Homestead Studio Suites Hotel',
#               'Chippenham Court',
#               'Mount Bethel Presbyterian Church',
#               'Raleigh Apartments',
#               'Marlon',
#               'Holm Oak Ln',
#               'Phyllis Drive',
#               'Ballyliffen Lane',
#               'Saxapahaw Run',
#               'Council of Interstate Testing Agencies, Inc.',
#               'Charter Square',
#               'Glitter',
#               'Winged Elm Lane',
#               'Monticello',
#               'Elam Court',
#               'Pony Pasture Court',
#               'Scott King Road',
#               'Norman Place',
#               'Tamarak Wood Court',
#               'Carr',
#               'Duncan Street',
#               'Ortons Point Place',
#               'Timerwind Drive',
#               'Grove Hollow Street',
#               'Parkersburg Street',
#               'South East Street',
#               'Tobacco Plus Mini Mart',
#               'Primrose School of West Cary',
#               'Mercury Court',
#               'Hulon Drive',
#               'Hickory Wood Square',
#               'Spreading Oak Court',
#               'Barry Street',
#               'Drew Lane',
#               'Bella Monica',
#               'Brewington Court',
#               'Briarhaven Drive',
#               'Venice Lane',
#               'Cheerful Court',
#               'Montclair Circle',
#               'Stoney Run Drive',
#               'Carpenter Town Ln',
#               'Crepe Myrtle Place',
#               'Trafalgar Place',
#               'The Clothing Warehouse',
#               'Bagwell Residence Hall',
#               'Langham Lane',
#               'Presley Court',
#               'Tandem Court',
#               'Brooktree Court',
#               'Fountain Ridge Road',
#               'Byerly Court',
#               'Silverton Court',
#               'Thompson Road',
#               'SPI Silver Back Life Headquarters',
#               'Optimist Park',
#               'Play It Again Sports',
#               'White Oak Avenue',
#               'Cary Amtrak Station',
#               'Windyrush Court',
#               'Capitol Square',
#               'Sandy Bluff Court',
#               'Friar Lane',
#               'Sanderling Court',
#               'East Canopy Oak Court',
#               'Drystone Drive',
#               'Crockett Court',
#               'Wyeth Avenue',
#               'Ambassador Loop',
#               'Warwickshire Way',
#               'Cary Fire Station #5',
#               'Lewis P Olds Wynd',
#               'Slatestone Court',
#               'Floyd Drive',
#               'Stewart Place',
#               'Lookout Mountain Road',
#               'South Roberson Street',
#               'Greywood Drive',
#               'Wynhurst Court',
#               'Douglas Elementary School',
#               'Collegiate Circle',
#               'Flanders Drive',
#               'Parnell Lane',
#               'Lowes Foods FreshSmart',
#               'Crescent Court',
#               'North Carolina Licensing Board for General Contractors',
#               'Randolph Court',
#               'Saint Andrews Presbyterian Church',
#               'Mapleside Ct',
#               'Timberlake Park',
#               'Circlebank Drive',
#               'The Crest',
#               'Chautauqua Avenue',
#               'Windbyrne Drive',
#               'Witherspoon Center Bicycle Parking',
#               'Groomsbridge Court',
#               'Green Level Church Road',
#               'Chowning Court',
#               'Wild Meadow Dr',
#               'Meadowmont Village Circle',
#               'Isley Street',
#               'Phillips Middle School',
#               'Doctors Express',
#               'Aloft Raleigh',
#               'Parkwood Baptist Church',
#               'Theodore Lane',
#               'EZ2778',
#               'Shem Creek Court',
#               'Peachland Drive',
#               'Jessamine Way',
#               'Cedar Ridge Trail',
#               'Byron & Virginia Kirkland',
#               'Pharmacy',
#               'Evergreen Community Church',
#               'Krispy Kreme',
#               'Second Baptist Church',
#               'This One',
#               'Natural Area/ Protected Watershed',
#               'Superior Court',
#               "Kilwin's",
#               'Hillmer Drive',
#               "Jessee's",
#               'Babylon Restaurant',
#               'Mrs. Cora Adams',
#               'Kellwood Court',
#               'La-Z-Boy Furniture Galleries',
#               'Enzo Court',
#               'Mira Mar Place',
#               'NCRR',
#               'Hull Avenue',
#               'Veranda Court',
#               'Willow Creek Laundromat',
#               'Delta Lake Drive',
#               'Johnson Lake Viewpoint',
#               'Lowry Avenue',
#               'East Chalfont Way',
#               'Umstead Forest Drive',
#               'Baileyfield Drive',
#               'Porter Dr',
#               'Brier Creek',
#               'HDRL Facilities',
#               'Fast Lube Plus',
#               'Palmetto Drive',
#               'Pasquotank Drive',
#               'Fossil Creek Court',
#               'Dusty Lane',
#               'Ellington Place',
#               'Somerknoll Drive',
#               'Stanopal Drive',
#               'Bournemouth Drive',
#               'Duck Pond Court',
#               'Crestwood',
#               "Taylor's Woods",
#               'Chelmsford Drive',
#               'Golf Course Drive',
#               'Gary Glen Boulevard',
#               'Montrose Street',
#               'Toxicology',
#               'Glendale Heights Park',
#               'Vineyard Lane',
#               'Worth',
#               'West Winmore Ave',
#               'Elevator',
#               'Sherlock Court',
#               'Public Hardware',
#               'Priestly Creek Drive',
#               'Portstewart Drive',
#               'Pops View Ln',
#               'Five Oaks Drive',
#               'Andrews Lane',
#               "Link's End Drive",
#               'University Marketplace',
#               'Research Lane',
#               'West Park Tavern',
#               'Hempstead Court',
#               'Strategic Dr',
#               'River Birch at Town Center Apartments',
#               'Margaret Louise Lane',
#               'Hanover Street',
#               'Velma Road',
#               'Briar Bridge Lane',
#               'Westgate Club Drive',
#               'Sea Glass Court',
#               'Waconda Court',
#               'Braeside Court',
#               'College Crest',
#               'Dorsett Drive',
#               'Bay Ridge Court',
#               'Tower Residential Quads',
#               'Mc Dowell Road',
#               'Wannamaker Drive',
#               'French Family Science Center',
#               'New Jerusalem Free Will Baptist Church',
#               'Bayshore Court',
#               "Joel Lane's Public House",
#               'Stratford Park',
#               'Northgate Park',
#               'Hazel Street',
#               'Stoney Branch Trail',
#               'Airport Rd BP',
#               'Alice Ingram Circle',
#               'Aiken Avenue',
#               'Ludwell Branch Ct',
#               'East Cornwall Road',
#               'Wood Spring Court',
#               'Chandlewood Knolls',
#               'Ashley Springs Ct',
#               'Hope Springs Lane',
#               'Woodhaven Court',
#               'Collander Drive',
#               'Kaitlin Drive',
#               'Y. E. Smith Elementary School',
#               'Godfrey Drive',
#               'Bryant Street',
#               'Cottonwood Drive',
#               'Brightwater Court',
#               'Wortham Drive',
#               'Fresenius Medical Care: Millbrook',
#               "Southpoint Children's Campus",
#               'Stromer Drive',
#               'O, P',
#               'Turlington Bike Rack 5',
#               'Stargrass Court',
#               'River Run',
#               'Martin Luther King Jr Street',
#               'Alliance Circle',
#               'Possum Track Road',
#               'Murphey Hall',
#               "Jimmy's Famous Hot Dogs",
#               'Langtree Lane',
#               'Downing Glen',
#               'North Carolina State University (Centennial Campus)',
#               'King Pond',
#               'Okelly Chapel Road',
#               'Beech Lake',
#               'Mercedes-Benz of Durham',
#               'Abby View Way',
#               'Annie Louise Wilkerson, MD Nature Preserve Park',
#               'Abbott Creek Trail',
#               'Midway Avenue',
#               'Graywick Way',
#               'Van Buren Road',
#               'Oakdale Farm Way',
#               'Piano & Organ Distributors',
#               'Preston Medical Group',
#               'Winterwood Drive',
#               'Westgrove Street',
#               'Talton Circle',
#               'Springfield Drive',
#               'Treesdale Lane',
#               'Spring Mountain Way',
#               'Penn Station',
#               'Laurel Creek',
#               'Atlantic Tire',
#               'Greenway Access',
#               'Edinshire St',
#               'Bonefish Grill',
#               'Country Trail',
#               'Central Church',
#               'De Mille Street',
#               'Defoe Ct',
#               'Jenkins Memorial United Methodist Church;All Saints Anglican Church',
#               'Dunstan Court',
#               'North Person Street',
#               'Garner Road',
#               'Sono',
#               'Fernhurst Court',
#               'Del Rio Drive',
#               'Fallswood Place',
#               'Southern Rail',
#               'Rosehaven Drive',
#               'Volvo of Cary',
#               'Market Street Coffee & Ice Cream',
#               'Idlewood Lane',
#               'Kilcullen Drive',
#               'Johnson Lexus of Durham',
#               'Ranger Road',
#               'Lorain Avenue',
#               'Lynwood Place',
#               'Ward Branch',
#               'Whitehead Road',
#               'Malta Avenue',
#               'Bethel Family Worship Center',
#               'Moores Creek Road',
#               'Six Forks Hills',
#               'Salsa Fresh',
#               'Millhouse Road',
#               'Winding Forest Trail',
#               'Whitlock Lane',
#               'Alero Road',
#               'Sowell Street',
#               'New West',
#               'Buxton Grant Drive',
#               'Inter-Faith Council for Social Service',
#               'Ballybrook Court',
#               'Nancy at FLOW salon',
#               'Bel Arbor Lane',
#               'Middle Varsity Lot Bike Rack',
#               'LocoPops',
#               'Arlen Park Drive',
#               'Halfmoon Court',
#               'Rubin Court',
#               'Streamview Court',
#               'Uptown Cheapskate',
#               'Fayetteville Road',
#               'Elmwood Avenue',
#               'Edgehill Parkway',
#               'Gemini Drive',
#               'Silverwood Creek Drive',
#               'Ashwick Court',
#               'Oxcroft Street',
#               'Arkelton Drive',
#               'Hickory Road',
#               'Bailey-Gallant House',
#               'Triangle Yoga',
#               'Ben Lloyd Drive',
#               'Talton Ridge Drive',
#               'The Pointe at Crabtree Apartments',
#               'Barley Circle',
#               'Wollston Court',
#               'Bellweather Court',
#               'Mutual Court',
#               'Arbutus Drive',
#               'Gray Hall',
#               'Chalfant',
#               'Traemoore Village',
#               'North Buchanan Boulevard',
#               'Convention Drive',
#               'Parkmist Circle',
#               'Smith Level Road',
#               'Cedar Village Lake',
#               'Edgewood',
#               'Ripley Court',
#               'Webb Street',
#               'Wills Grove at Alyson Pond',
#               'Daniel Road',
#               'Converse Road',
#               'Cape Cod Drive',
#               'Prospector Place',
#               'Weber Court',
#               'North Ridge Post Office',
#               'Mansfield Drive',
#               'Drystack Way',
#               'Skylark Drive',
#               'Rollingwood',
#               'Park on Millbrook Office Condominiums',
#               'Orleans Place',
#               'Glendale Drive',
#               'Ivy Hollow Court',
#               'Dixie Garden Drive',
#               'City of Oaks Wynd',
#               'Rolling Green Court',
#               'Bristol Road',
#               'Sandstone Ridge Court',
#               'Forest Ridge Drive',
#               'Bell Preston Reserve Apartments',
#               'Mollington Court',
#               'Upchurch Farm Road',
#               'The Gates Drive',
#               'Woodland Pond',
#               'Doc Nichols Road',
#               'Oak Point Court',
#               'Brevard Place',
#               'Diploma Drive',
#               'Matthews Lake Dam',
#               'Billie Holliday Court',
#               'Ravens Point Circle',
#               'Revolution',
#               'North Lassiter',
#               'Reunion Pt',
#               'Banner Street',
#               'Cave Creek Court',
#               'Pine Grove Road',
#               'Yates Store Road Street-Side Trail',
#               'Ehringhaus Field',
#               'Sunscape Lane',
#               'Park View Baptist Church',
#               'Stone Lion Drive',
#               'Bridges at Chapel Hill',
#               'Sevier Street',
#               'Oddysey Drive',
#               'Tide Court',
#               'Common Ground Green Building Center',
#               'Old Vanteen Ln',
#               'Hanes House',
#               'Engineering Building II',
#               'Carrboro Yoga Company',
#               'Griffis Street',
#               'Quail Forest Drive',
#               'Parkway Pointe',
#               'Shennandoah',
#               'Santa Anita Lane',
#               'Ridgefield Road',
#               'Waterford Village Place',
#               'Dearborn Drive',
#               'Bright Beginnings',
#               'Cloud Crossing Circle',
#               'Sunbeam Way',
#               'Regal Brier Creek Cinema 14',
#               'SpineCare Chiropractic',
#               'North Carolina Correctional Institution for Women',
#               'Riversville Court',
#               'Herrick Place',
#               'Sutter Gate Lane',
#               'Lidgerwood Lane',
#               'Sushi O Bistro',
#               'Wingman',
#               'West Circuit Drive',
#               'Dunbar Road',
#               'Patel Brothers',
#               'Thomas A. Bell, DDS',
#               'Oakbrook Circle',
#               'Few Circle',
#               'Daybrook Circle',
#               'Cherrytree Circle',
#               "Zaxby's",
#               'Forest Hills',
#               'Shari Court',
#               'Union Street',
#               'West Orange Street',
#               'Hay Sedge Court',
#               'Bessie Wilson',
#               'Pinchot Lane',
#               'Cinco de Mayo',
#               'Angier Avenue',
#               "O'Hara Court",
#               'North Carolina School of Science and Math',
#               'Baybridge Park',
#               'EZ2773',
#               'Springstop Lane',
#               'North State Bank',
#               'Summit Arbor Drive',
#               'Green Street',
#               'Brook Run Drive',
#               'Lewey Drive',
#               'Long Lake Terrace',
#               'Immaculata Catholic School',
#               'Julie Court',
#               'Mez Contemporary Mexican',
#               'The Cave',
#               'Creek Run Court',
#               'Sarazen Place',
#               'Montauk Drive',
#               'Great Oak Court',
#               'Culbreth Ridge',
#               'Little Creek Road',
#               'Shelly Place',
#               'Austin Quality Foods',
#               'West Main Street',
#               'Bruton Drive',
#               'Lakeview Section of Budleigh',
#               'Long Meadows Road',
#               'Perry Creek',
#               'Alston Road',
#               'Just Fit Tailors',
#               'Tanager Lane',
#               'Barksdale Drive',
#               'Raj Drive',
#               'ATT Parking',
#               'Buckhead Drive',
#               'Chatham Lane',
#               'Glen Forest',
#               'Harvest Ridge',
#               'Margaret Avenue',
#               'Farnborough Road',
#               'Carpenter Creek Place',
#               'Rex Hospital',
#               'Carson Road',
#               'Thoreau Drive',
#               'Landreth Court',
#               'Huntingdon Drive',
#               'Nolichucky Court',
#               'Safeway Street',
#               'Holt Drive',
#               'Tulip Poplar Circle',
#               'Craig Hill Lane',
#               'Higgins Greenway',
#               'Donovan Place',
#               'Intuition Circle',
#               'North Miami Boulevard',
#               'Westview Cove',
#               'Cambay Court',
#               'Cox Avenue',
#               'Belmont Ridge',
#               'Valley Forge Road',
#               'Durants Neck Lane',
#               'Lea Court',
#               'Bromfield Way',
#               'Mini City',
#               'Ruby Street',
#               'Whispering Oak Lane',
#               'Oak Avenue',
#               'Amber Alley',
#               'Disciples Church of Christ',
#               'Hamilton Hedge Place',
#               'Old Stone Crossing',
#               'Southland Drive',
#               'Cranborne Lane',
#               'Callard Run',
#               'Anthony Drive',
#               'Sherringham Court',
#               'Parker Herndon Road',
#               'Pearsontown Elementary School',
#               'Trimble Court',
#               'Alemany Street',
#               'Broadlands Drive',
#               'Wesker Circle',
#               'Center Street',
#               'Banbury Woods',
#               'Rock Creek Lane',
#               'Wasser Court',
#               'Lewey Stone Court',
#               'Corbin Hill Circle',
#               'Sparta Street',
#               "Maggiano's",
#               'Neville Street',
#               'Tylerton Drive',
#               'Blue Ridge Court',
#               'Ellen Way',
#               'Mixboro Drive',
#               'Clearport Drive',
#               'Hamilton Court',
#               'Bucksport Lane',
#               "Kroger's",
#               'Gunston Place',
#               'Jennel Way',
#               'Lash Avenue',
#               'Wilson Hall',
#               'Advance Auto Parts: Store 6857',
#               'Wilkerson Avenue',
#               'Morven Place',
#               'Village Crossing Drive',
#               'South Berrymeadow Lane',
#               'Keystone Drive',
#               'Ivy Tree Place',
#               'Kimberly Drive',
#               'Flower Bed Court',
#               'Hampton Valley Road',
#               'Foresight Drive',
#               'Ridge Wood Street',
#               'Bessborough Drive',
#               'Herbert E. Norris Home Property',
#               'Iverness Drive',
#               'Brooks Elementary School',
#               'Williamstowne Square',
#               'J D Clement Early College High School',
#               'Bloomsbury Park',
#               'Raleigh Executive Park',
#               'Hodges Street',
#               'Big Bend Foot Trail',
#               'Duke Gardens Bike Rack',
#               'AniMall',
#               'The Atrium',
#               'Sandy Creek Drive',
#               'Marilyn Lane',
#               'Barningham Court',
#               'Chesden Drive',
#               'North Parking Deck',
#               'Lincoln Villas',
#               'Detail Drive',
#               'Student Rural Health Coalition of North Carolina',
#               'Newgate Court',
#               'Longview - The Poe House',
#               'Timber Drive',
#               'Eubanks Road',
#               'Broomfield Terrace',
#               'Gorman Street',
#               'Industrial Drive',
#               'Lariat Lane',
#               'McSwiney Drive',
#               'Farm Gate Avenue',
#               'Tyler’s Restaurant & Taproom',
#               'Salvation Is Free Holy Church',
#               'Wild Food & Herb Market',
#               'C',
#               'Harry Tucker, Hornaday & Faucette',
#               "Townridge Shopping Center: Landlord's Room",
#               'Regents Park Apartments',
#               'Amaris Lane',
#               'Quincy Court',
#               '17 Alley',
#               'Hedgelawn Way',
#               'Gisborne Court',
#               'Wells Fargo',
#               'Caswell',
#               'Atkinson Hall',
#               'Cool Vista Lane',
#               'Sunset Terrace',
#               'Re-Bath of the Triangle',
#               'Scale Bark Road',
#               'McCoy Court',
#               'Shofield Court',
#               'Redwood Drive',
#               'Loring Ct',
#               'Sourwood Circle',
#               'Clark Avenue',
#               'Wycombe Lane',
#               'Wolfpack Basketball',
#               'Bluestone Drive',
#               'John Wimbish Property',
#               'Silo Drive',
#               'Flying Saucer Draught Emporium',
#               'Swithland Court',
#               'Viaduct Building',
#               'Sycamore Lake',
#               'Millbrook KinderCare',
#               'Hollenden Place Apartments',
#               'Nature Trail Lane',
#               'Anita Street',
#               'CNBC News',
#               'Albacore Lane',
#               'Little Stone Circle',
#               'Marriott Downtown Raleigh',
#               'Austin Pond Drive',
#               'Birstall Drive',
#               'Edgemont Drive',
#               'Horsepen Place',
#               'Caspian Hall',
#               'Dove Cottage Lane',
#               'Friendly Drive',
#               'Lapis Lane',
#               'Village Lawn Drive',
#               'Helena Court',
#               'Skylark Tailors',
#               'Creststone Drive',
#               'Waterview Court',
#               'Paxford Ct',
#               'Church of God of Prophecy Assembly Life Center',
#               'Navaho Drive',
#               'Merriane Drive',
#               'Aspenwald',
#               'Altmont Court',
#               'Old Heritage Court',
#               "John's Woods Road",
#               'Wooden Road',
#               'REEDS Jewelers - Crabtree Valley Mall',
#               'Grosvenor Drive',
#               'Prairie Pond Cir',
#               'Baileywick Trail',
#               'Compound at Bartons Creek',
#               'Vicksburg Drive',
#               'Kilary Drive',
#               'Glen Erin Way',
#               'North Corncrib Court',
#               'Agnes Street',
#               'Southbridge Drive',
#               'American Tobacco Trail Wimberly Access',
#               'K&L Gates, LLP',
#               'Fleetwood Street',
#               'Alexander Square Parking Deck',
#               'Clark Ridge Court',
#               'Hudson News/AeroMart',
#               'Hicks Street',
#               'Bacon Street',
#               'Granville Towers South',
#               'Fayetteville Street Elementary School',
#               'Powder Mill Road',
#               'Glen Bonnie Lane',
#               'The Groves at Fairway Apartments',
#               'Tattershale Court',
#               'Hasbrouck Drive',
#               'Wakewood Court',
#               'Hinton James Residence Hall',
#               'Mountain Brook Circle',
#               'Junction',
#               'Chatford Drive',
#               'Henry N. Hawkins',
#               'Brandy Wood Court',
#               'Weston Oaks',
#               'Windsor Forest',
#               'Angela Way',
#               'Wedgeland Drive',
#               'Wedgewood Lane',
#               'Bella Italia',
#               'Mc Allister Place',
#               'The Birkshires at Town Hall Commons',
#               'Corcoran Street Garage and Lot',
#               'Leafcrest Court',
#               'Lyon Farm Drive',
#               "North Carolina State Employees' Credit Union",
#               'Judah Benjamin Court',
#               'Spencor Mill Road',
#               'Berkshire Manor',
#               'Cross Timbers Drive',
#               'Breakfast',
#               'Cedarwood Drive',
#               'Forestwood Drive',
#               'Fowle Street',
#               'Carrington Drive',
#               'Beth Meyer Synagogue',
#               'Lindenshire Road',
#               'Parking and Transportation Services',
#               'Kobold Drive',
#               'Oval Park Place',
#               'Colony Professional Center',
#               'Orford Court',
#               'Mill Village Commons',
#               'Avery Dr',
#               'Preston Springs Lane',
#               'Boyle Street',
#               'Folkner Trail',
#               'Adlie Drive',
#               'Pat Drive',
#               'David Stone Dr',
#               'Hogan Hills Rd',
#               'E Main St at Arts Center Plaza',
#               '30 Alley',
#               'District Drive Park & Ride',
#               'San Mateo Place',
#               '140 Salon & Dry Bar',
#               'Stacy Street',
#               'Springdale Gardens',
#               'Walltown Ministries',
#               'Triangle Expressway',
#               'Fidelity Drive',
#               'Alexander Drive',
#               'Wilson Park',
#               'Miramar Place',
#               'Valley Court',
#               'North Ridge Square',
#               'Salt Box Village',
#               'Mary E. Phillips High School',
#               'Marsh Court',
#               'Akal Court',
#               'Total Source Realty',
#               'West Williams Street',
#               'Sitar',
#               'Morrisville Fire Station 1',
#               'Bent Branch Court',
#               'Durham Fire Station Number 13',
#               'Crabtree Center',
#               'Pine Knoll',
#               'Denson Drive',
#               'Mayo Street',
#               '21 Alley',
#               'Terminal 1',
#               'Shady Maple Court',
#               'Warren Avenue',
#               'Wadsworth Avenue',
#               'Halberd Court',
#               'Homewood Drive',
#               'Kilearn Mill Court',
#               'Bear Lane',
#               'Swain',
#               'East Peace Street',
#               'Carbe Court',
#               'Putters Court',
#               'Tafton Court',
#               'Wimbish Lane',
#               'Sand Pebble Place',
#               'Alfred Street',
#               'Vaughn Street',
#               'Estes Drive',
#               'Fraternity Court',
#               'Lyndfield Close',
#               'Parkwood Volunteer Fire Department',
#               'Middleton Road',
#               'Hudson Street',
#               'Monteith Engineering Research Center',
#               'Cambridge Woods',
#               'Linden Park Lane',
#               'University Station Road',
#               'Mini City Marketplace',
#               'Chipotle',
#               'Traphill Drive',
#               ...},
#              'Chatham,North Carolina,N.C.,NC,USA': {'Farrington',
#               'Fearrington',
#               'Fearrington Village'},
#              'Duke University': {'',
#               'A/C Chiller',
#               'Alexander H Sands Jr Building',
#               'Alspaugh Residence Hall',
#               'Art Building',
#               'Aycock Residence Hall',
#               'Baldwin Auditorium',
#               'Bassett Residence Hall',
#               'Bell Tower Residence Hall',
#               "Bishop's House",
#               'Bivins Building',
#               'Blackwell Residence Hall',
#               'Brown Residence Hall',
#               'Carr Building',
#               'Crowell Building',
#               'Duke University West Campus',
#               'East Campus Union Building',
#               'East Duke Building',
#               'Edwin L. Jones Bldg',
#               'Epworth Residence Hall',
#               'Finch-Yaeger Building',
#               'Friedl Science Building',
#               'Gilbert-Addoms Residence Hall',
#               'Giles Residence Hall',
#               'Jarvis Residence Hall',
#               'Levine Science Research Center',
#               'Lilly Library',
#               'Mary Duke Biddle Music Building',
#               'Medical Sciences Research Building',
#               'Memorial Gym Bodie Recreation Center',
#               'Mudd Building',
#               'Nanaline Duke',
#               'Pegram Residence Hall',
#               'Pre-Major Advising Center',
#               'Randolph Residence Hall',
#               'Richard White Lecture Hall',
#               'Southgate Residence Hall',
#               'The Ark',
#               'Wallace Wade Stadium',
#               'West Duke Building',
#               'Wilson Residence Hall'},
#              'Durham,North Carolina,N.C.,NC,USA': {'American Village',
#               'Archer Woods',
#               'Bethesda',
#               'Bilboa',
#               'Blands',
#               'Braggtown',
#               'Brassfield',
#               'Burton',
#               'Chicopee Hills',
#               'Colony Park',
#               'Devonshire Manor',
#               'Durham',
#               'Eastwood Park',
#               'Falconbridge',
#               'Few',
#               'Five Oaks',
#               'Forest Acres',
#               'Genlee',
#               'Glen Forest',
#               'Gorman',
#               'Hayes',
#               'Hickory Oaks',
#               'Hope Valley North',
#               'Hope Valley West',
#               'Huckleberry Spring',
#               'Joyland',
#               'Keene',
#               'Lochnora',
#               'Lowes Grove',
#               'Lynn Crossroads',
#               'Marydell',
#               'Mill Grove',
#               'Nelson',
#               'New Hope Valley',
#               'Oak Grove',
#               'Parkwood',
#               'Redwood',
#               'Rocky Knoll',
#               'Spring Valley',
#               'Surry Green',
#               'The Downs',
#               'University Estates',
#               'Weaver',
#               'West Hills',
#               'West Hills East',
#               'Woodberry',
#               'Woodcroft'},
#              'Ellerbee Creek Watershed Association': {'17 Acre Wood Preserve'},
#              'North Carolina School of Science and Math': {'',
#               'Beall',
#               'Cottage',
#               'Educational Technology Complex',
#               'Hill',
#               'Hunt',
#               'Maintenance',
#               'Physical Education Center',
#               'Reynolds',
#               'Royall Center',
#               'Watts'},
#              'North Carolina,N.C.,NC,USA': {'Durham', 'Wake'},
#              'Orange,North Carolina,N.C.,NC,USA': {'Ashley Forest',
#               'Barrington Hills',
#               'Birchwood Lake Estates',
#               'Blackwood',
#               'Briarcliff',
#               'Calvander',
#               'Carlton Acres',
#               'Carol Woods',
#               'Carrboro',
#               'Cedar Hill',
#               'Chapel Hill',
#               'Clark Hills',
#               'Coker Hills',
#               'Colonial Heights',
#               'Colony Park',
#               'Colony Woods',
#               'Cornwallis Hills',
#               'Coventry',
#               'Davie Circle',
#               'Dogwood Acres',
#               'Eastowne',
#               'Elkins Hills',
#               'Eno',
#               'Estes Hills',
#               'Eubanks',
#               'Falls of New Hope',
#               'Farrington Hills',
#               'Fox Meadows',
#               'Glen Heights',
#               'Glen Lennox',
#               'Greenbriar',
#               'Greenwood',
#               'Hidden Hills',
#               'Hideaway Estates',
#               'High Park',
#               'Ironwoods',
#               'Jappa Oaks',
#               'Kensington Trace',
#               'Lake Ellen',
#               'Lake Forest Estates',
#               'Lakewoods',
#               'Laurel Springs',
#               'Manor Hill',
#               'Morgan Creek Hills',
#               'Mount Bolus',
#               'New Hope',
#               'North Forest Hills',
#               'Northwood',
#               'Oak Hills',
#               'Pine Knob',
#               'Plantation Acres',
#               'Quail Run',
#               'Ridgefield',
#               'Ridgefield Park',
#               'Sedgefield',
#               'Southbridge',
#               'Spring Valley',
#               'Stagecoach Run',
#               'Stoneridge',
#               'Stoney Brook',
#               'Strayhorn Hills',
#               'Summerfield Crossing',
#               'Sunshine Acres',
#               'Tenney Circle',
#               'The Highlands',
#               'The Meadows',
#               'The Oaks',
#               'The Oaks II',
#               'The Woods at Laurel Hill',
#               'Timbercrest',
#               'Timberlyne',
#               'University',
#               'University Acres',
#               'Walnut Cove',
#               'Weatherhill',
#               'Whispering Pines',
#               'Wildwood',
#               'Wildwood Springs',
#               'Windy Hill Farm'},
#              'Pearsontown Elementary School': {''},
#              'Raleigh, NC': {''},
#              'Southwest Elementary School': {''},
#              'US': {'Raleigh-Durham International Airport'},
#              'Wake,North Carolina,N.C.,NC,USA': {'Asbury',
#               'Bayleaf',
#               'Caraleigh',
#               'Carpenter',
#               'Cary',
#               'Clegg',
#               'Falls',
#               'Isle Forest',
#               'Kildaire Farms',
#               'Leesville',
#               'Markwood',
#               'Method',
#               'Millbrook',
#               'Morrisville',
#               'Mount Vernon',
#               'New Light',
#               'Northwoods',
#               'Orchards',
#               'Pickwick Village',
#               'Raleigh',
#               'Six Forks',
#               'Stony Hill',
#               'Tysonville',
#               'Upchurch',
#               'Weston',
#               'Williamsburg Manor'}})

# %% [markdown]
# ##### Audit zip codes
# Zip codes can be of the format 12345-1234.  Review the first part of the zip code.

# %%
def is_zip(elem):
    return (elem.attrib['k'] == 'addr:postcode')

def audit_zip(osmfile):
    zips = []
    for event, elem in ET.iterparse(osmfile, events=('start',)):
        if elem.tag == 'node' or elem.tag == 'way':
            for tag in elem.iter('tag'):
                if is_zip(tag):
                    zips.append(tag.attrib['v'].split('-')[0])
    return zips

# %%
zip_count = Counter(audit_zip(map_file))

# %%
zip_count.most_common()
# Out:
# [('27612', 1692),
#  ('27560', 1515),
#  ('27609', 1131),
#  ('27519', 880),
#  ('27701', 667),
#  ('27705', 480),
#  ('27615', 352),
#  ('27510', 313),
#  ('27514', 168),
#  ('27513', 117),
#  ('27511', 116),
#  ('27606', 97),
#  ('27707', 95),
#  ('27601', 90),
#  ('27516', 87),
#  ('27517', 72),
#  ('27704', 59),
#  ('27703', 53),
#  ('27713', 48),
#  ('27617', 36),
#  ('27603', 29),
#  ('27613', 29),
#  ('27607', 21),
#  ('27604', 19),
#  ('27610', 15),
#  ('27605', 13),
#  ('27614', 10),
#  ('27608', 9),
#  ('27695', 5),
#  ('27162', 4),
#  ('27518', 4),
#  ('27616', 3),
#  ('NC', 3),
#  ('27895', 2),
#  ('27599', 2),
#  ('27602', 2),
#  ('27708', 2),
#  ('27709', 1),
#  ('28616', 1),
#  ('275198404', 1),
#  ('2612', 1),
#  ('275199', 1),
#  ('275609194', 1),
#  ('27502', 1),
#  ('27710', 1),
#  ('277030', 1)]

# %% [markdown]
# ##### Audit cities

# %%
def is_city(elem):
    return (elem.attrib['k'] == 'addr:city')

def audit_city(osmfile):
    cities = []
    for event, elem in ET.iterparse(osmfile, events=('start',)):
        if elem.tag == 'node' or elem.tag == 'way':
            for tag in elem.iter('tag'):
                if is_city(tag):
                    cities.append(tag.attrib['v'])
    return cities

# %%
cities_count = Counter(audit_city(map_file))

# %%
cities_count
# Out:
# Counter({'Apex': 1,
#          'Carrboro': 336,
#          'Cary': 2668,
#          'Chapel Hill': 470,
#          'Chapel Hill, NC': 1,
#          'Durham': 1287,
#          'Morrisville': 1557,
#          'Ra': 1,
#          'Raleigh': 874,
#          'Research Triangle Park': 1,
#          'Wake Forest': 2,
#          'cary': 1,
#          'chapel Hill': 2,
#          'durham': 2,
#          'raleigh': 2})

# %% [markdown]
# ##### Create a general audit function to return the values of a specified tag

# %%
def audit (osmfile, target_key):
    results = []
    for event, elem in ET.iterparse(osmfile, events=('start',)):
        if elem.tag == 'node' or elem.tag == 'way':
            for tag in elem.iter('tag'):
                if tag.attrib['k'] == target_key:
                    results.append(tag.attrib['v'])
    return results

# %%
cities_count = Counter(audit(map_file,'addr:city'))

# %%
house_number_count = Counter(audit(map_file,'addr:housenumber'))

# %%
house_numbers = audit(map_file,'addr:housenumber')

# %%
#What percentage of the house numbers are numeric:
numeric = 0
for i in house_numbers:
    if i.isnumeric():
        numeric += 1
print (numeric/len(house_numbers))
# Out:
# 0.9815342934550121

# %%
first_digit = []
for i in house_numbers:
    first_digit.append(i[0])

# %%
Counter(first_digit)
# Out:
# Counter({'#': 3,
#          '1': 4731,
#          '2': 2741,
#          '3': 1312,
#          '4': 1708,
#          '5': 1549,
#          '6': 589,
#          '7': 604,
#          '8': 491,
#          '9': 292,
#          'A': 1,
#          'B': 1,
#          'J': 1,
#          'S': 3})

# %%
house_number_count
# Out:
# Counter({'311 B': 1,
#          '#200': 1,
#          '5731': 1,
#          '4135': 1,
#          '238': 3,
#          '5404': 9,
#          '7033': 2,
#          '1936': 1,
#          '4800': 12,
#          '4424': 1,
#          '320': 15,
#          '7108': 1,
#          '8504': 8,
#          '2722': 3,
#          '1230': 2,
#          'A': 1,
#          '906': 4,
#          '375': 1,
#          '209': 61,
#          '2009': 18,
#          '4140': 1,
#          '3560': 1,
#          '401': 40,
#          '1371': 1,
#          '601 A': 1,
#          '8313': 1,
#          '3761': 1,
#          '7328': 1,
#          '3200': 4,
#          '5779': 1,
#          '4141': 1,
#          '122': 23,
#          '746': 2,
#          '1401': 9,
#          '805': 18,
#          '5218': 1,
#          '2429': 1,
#          '3004 Suite C': 1,
#          '130': 15,
#          '5722': 1,
#          '354': 1,
#          '403': 42,
#          '1257': 1,
#          '9812': 1,
#          '8414': 1,
#          '7404': 1,
#          '611': 10,
#          '4015': 1,
#          '812': 8,
#          '1191': 1,
#          '505a': 1,
#          '737': 4,
#          '5015': 4,
#          '918': 5,
#          '503': 22,
#          '1027': 3,
#          '48': 1,
#          '358': 1,
#          '5035': 1,
#          '1608': 3,
#          '3817': 1,
#          '6631': 1,
#          '1820': 5,
#          '2748': 1,
#          '6009': 1,
#          '2032': 3,
#          '2104': 8,
#          '913b': 1,
#          '2406': 3,
#          '1769': 1,
#          '2624': 4,
#          '435': 1,
#          '2855': 1,
#          '3102': 2,
#          '5069': 1,
#          '8101': 1,
#          '3211 University Dr': 1,
#          '1317a': 1,
#          '100': 231,
#          '400 1/2': 1,
#          '231': 3,
#          '1600': 8,
#          '26': 1,
#          '211, 213': 1,
#          '3540': 1,
#          '6128': 1,
#          '639': 1,
#          '1103': 4,
#          '610': 13,
#          '3417': 1,
#          '6101': 1,
#          '8409': 1,
#          '528': 1,
#          '1504': 6,
#          '1046': 1,
#          '263,265,267,269': 1,
#          '534': 1,
#          '2840': 2,
#          '8855': 1,
#          '5106': 3,
#          '8604': 4,
#          '992': 1,
#          '328': 7,
#          '315': 14,
#          '5537': 1,
#          '2108': 11,
#          '911': 7,
#          '327b': 1,
#          '10351': 1,
#          '3109': 2,
#          '6001': 2,
#          '4158': 1,
#          '512': 10,
#          '4348': 1,
#          '6716': 1,
#          '2121': 11,
#          '5101': 10,
#          '5303': 1,
#          '5009': 11,
#          '638': 1,
#          '5114': 1,
#          '1425': 1,
#          '5508': 3,
#          '1791': 2,
#          '106 B': 1,
#          '237': 4,
#          '2118': 7,
#          '9801': 2,
#          '6286-100': 1,
#          '3915': 1,
#          '220': 28,
#          '407': 36,
#          '607': 9,
#          '6260-100': 1,
#          '4611': 4,
#          '4313': 2,
#          '942': 1,
#          '2880': 1,
#          '101': 209,
#          '289': 1,
#          '4028': 2,
#          '8413': 1,
#          '713': 14,
#          '6832': 1,
#          '925': 2,
#          '7432': 1,
#          '4710': 5,
#          '1416': 2,
#          '5812': 4,
#          '7824': 2,
#          '247': 2,
#          '5530': 1,
#          '5013': 5,
#          '7950': 1,
#          '2311': 4,
#          '5751': 1,
#          '516': 10,
#          '4725': 4,
#          '201c': 1,
#          '1064': 1,
#          '1914': 2,
#          '5806': 1,
#          '5454': 1,
#          '504': 29,
#          '1133': 2,
#          '2505': 11,
#          '5427': 1,
#          '4747': 2,
#          '502 B': 1,
#          '8825': 1,
#          '1704': 3,
#          '1739': 1,
#          '1011': 4,
#          '2434': 1,
#          '5609': 8,
#          '4325': 1,
#          '3043': 1,
#          '20': 2,
#          '4608': 13,
#          '6638': 1,
#          '361': 2,
#          '1115': 4,
#          '8304': 3,
#          '3809': 2,
#          '1811': 1,
#          '1853': 1,
#          '4822': 3,
#          '226': 6,
#          '5241': 1,
#          '2522': 1,
#          '8108': 1,
#          '5332': 1,
#          '8625': 1,
#          '8305': 2,
#          '962': 1,
#          '2771': 1,
#          '1514': 2,
#          '1055': 2,
#          '2718': 2,
#          '414': 13,
#          '8200-1003': 1,
#          '2850': 1,
#          '2013': 13,
#          '842': 1,
#          '1921': 5,
#          '10303': 1,
#          '5102': 2,
#          '4203': 3,
#          '719': 4,
#          '1508': 4,
#          '2694': 1,
#          '1141': 2,
#          '9201': 1,
#          '4525': 4,
#          '6202': 1,
#          '1209': 14,
#          '5401': 9,
#          '713, 715': 1,
#          '269': 1,
#          '8201': 1,
#          '5439': 1,
#          '1375': 2,
#          '4803': 5,
#          '138': 6,
#          '5321': 7,
#          '704-2': 1,
#          '2801': 1,
#          '3331': 1,
#          '4702': 6,
#          '2514': 2,
#          '706': 10,
#          '7024': 2,
#          '2811': 3,
#          '108;110': 1,
#          'Suite 201': 1,
#          '719 A': 1,
#          '3110': 1,
#          '6632': 1,
#          '1014': 6,
#          '2445': 2,
#          '816': 5,
#          '5603': 2,
#          '2821': 1,
#          '2735': 2,
#          '723': 5,
#          '264': 1,
#          '4025': 2,
#          '5215': 2,
#          '733': 4,
#          '833': 5,
#          '1122': 4,
#          '107-C': 1,
#          '9425': 1,
#          '720': 8,
#          '2813': 3,
#          '618': 4,
#          '5781': 1,
#          '408 B': 1,
#          '5112': 5,
#          '2001': 17,
#          '9808': 1,
#          '431': 3,
#          '3813': 3,
#          '8511': 2,
#          '2503': 7,
#          '113': 73,
#          '230': 10,
#          '373': 1,
#          '4830': 4,
#          '4512': 10,
#          '6916': 1,
#          '729': 4,
#          '6017': 1,
#          '1840': 1,
#          '2900': 3,
#          '4000': 3,
#          '2529': 1,
#          '4303': 1,
#          '1927': 1,
#          '211': 47,
#          '1200-A': 1,
#          '5033': 3,
#          '5524': 2,
#          '7524': 1,
#          '1824': 2,
#          '3412': 1,
#          '1215': 4,
#          '242': 3,
#          '422': 3,
#          '1153': 1,
#          '1028': 2,
#          '2530': 1,
#          '4904': 5,
#          '944': 1,
#          '2251': 1,
#          '6767': 1,
#          '2015': 8,
#          '2437': 1,
#          '3218': 1,
#          '2526': 1,
#          '5059': 1,
#          '1127': 2,
#          '1041': 6,
#          '2749': 1,
#          '5017': 6,
#          '4826': 5,
#          '419': 9,
#          '3104': 2,
#          '508a': 2,
#          '5402': 3,
#          '3036': 2,
#          '4317': 1,
#          '5227': 1,
#          '277': 1,
#          '292': 1,
#          '1920': 4,
#          '520': 6,
#          '1641': 1,
#          '5408': 8,
#          '295': 1,
#          '1006': 6,
#          '2512': 6,
#          '1367': 1,
#          '6736': 1,
#          '2525': 1,
#          '1410': 1,
#          '7708': 3,
#          '291': 1,
#          '5601': 7,
#          '5109': 8,
#          '3413': 1,
#          '3112': 1,
#          '2409': 1,
#          '811': 7,
#          '540': 2,
#          '293': 1,
#          '82': 1,
#          '3127': 1,
#          '5124': 1,
#          '510a': 1,
#          '5419': 3,
#          '507b': 1,
#          '5608': 9,
#          '6637': 1,
#          '10321': 1,
#          '4417': 4,
#          '5456': 1,
#          '8605': 5,
#          '814b': 1,
#          '762': 3,
#          '6014': 2,
#          '501b': 1,
#          '4921': 6,
#          '3205': 1,
#          '4820': 4,
#          '175': 2,
#          '6712': 1,
#          '909': 8,
#          '1724': 1,
#          '2633': 1,
#          '700 B': 1,
#          '827': 2,
#          '3508': 1,
#          '862': 3,
#          '7725': 1,
#          '1123': 2,
#          '2040': 1,
#          '2433': 1,
#          '875': 1,
#          '104b': 1,
#          '5513': 6,
#          '1832': 3,
#          '801': 20,
#          '2610': 2,
#          '4604': 17,
#          '7600': 2,
#          '5122': 1,
#          '2005': 18,
#          '4817': 3,
#          '642': 5,
#          '731 B': 1,
#          '1852': 1,
#          '727': 4,
#          '84': 1,
#          '1935': 1,
#          '7704': 2,
#          '1004a': 2,
#          '3408': 2,
#          '10550': 1,
#          '5121': 2,
#          '760': 2,
#          '4447': 1,
#          '2705': 4,
#          '707': 10,
#          '907': 6,
#          '2103': 8,
#          '994': 1,
#          '1436': 1,
#          '2533': 1,
#          '2101': 12,
#          '2039': 1,
#          '233': 5,
#          '4625': 3,
#          '1208': 11,
#          '4718': 2,
#          '3708': 2,
#          '602': 19,
#          '7216': 2,
#          '1258': 1,
#          '1128': 5,
#          '4902': 3,
#          '733 A': 1,
#          '1512': 1,
#          '5462': 1,
#          '4620': 6,
#          '1007': 8,
#          '2612': 5,
#          '1060': 2,
#          '547': 1,
#          '2006': 13,
#          '5800': 5,
#          '1532': 1,
#          '2207': 4,
#          '5484': 1,
#          '8320': 1,
#          '2301': 8,
#          '3025': 4,
#          '544': 1,
#          '1909': 7,
#          '8732': 1,
#          '8225': 1,
#          '947': 1,
#          '4100': 3,
#          '507': 22,
#          '7025-4': 1,
#          '6801': 2,
#          '201': 84,
#          '5912': 1,
#          '3010': 3,
#          '139': 4,
#          '553': 1,
#          '508': 20,
#          '1250': 1,
#          '2114': 7,
#          '9&15': 1,
#          '2405': 3,
#          '1117': 8,
#          '765': 1,
#          '2812': 3,
#          '5315': 2,
#          '4048': 1,
#          '2751': 2,
#          '1070': 2,
#          '1925': 3,
#          '615': 10,
#          '319': 16,
#          '9632': 1,
#          '4846': 1,
#          '126': 20,
#          '771': 1,
#          '8728': 1,
#          '4053': 1,
#          '514': 7,
#          '4003': 2,
#          '1150': 2,
#          '1256': 2,
#          '4409': 9,
#          '8616': 1,
#          '1729': 1,
#          '9611': 1,
#          '1255': 1,
#          '1606': 1,
#          '2738': 1,
#          '1025': 7,
#          '5305': 10,
#          '154': 1,
#          '438': 1,
#          '5044': 1,
#          '5324': 4,
#          '4044': 1,
#          '3833': 2,
#          '4204': 5,
#          '1391': 1,
#          '914': 6,
#          '5410-8': 1,
#          '4237': 1,
#          '321': 11,
#          '8536': 1,
#          '2449': 1,
#          '5415': 3,
#          '4621': 5,
#          '2332': 1,
#          '2206': 7,
#          '931': 1,
#          '1261': 1,
#          '4017': 1,
#          '402': 37,
#          '6210': 1,
#          '6662': 1,
#          '400': 38,
#          '6136': 1,
#          '8613': 5,
#          '1111': 6,
#          '416': 13,
#          '4807': 1,
#          '408 A': 1,
#          '4057': 1,
#          '317': 15,
#          '3705': 4,
#          '2733': 2,
#          '2604': 8,
#          '5327': 1,
#          '3586': 1,
#          '143': 6,
#          '2917': 1,
#          '5901': 1,
#          '1207': 3,
#          '1644': 1,
#          '932': 1,
#          '1107': 5,
#          '853': 1,
#          '2218': 2,
#          '2203': 6,
#          '2422': 2,
#          '1639': 1,
#          '2685': 1,
#          '7016': 3,
#          '6274-100': 1,
#          '4516': 9,
#          '5718': 2,
#          '611b': 1,
#          '1009a': 1,
#          '241': 2,
#          '5486': 1,
#          '2641': 1,
#          '803 C': 1,
#          '2510': 6,
#          '1525': 2,
#          '9519': 1,
#          '3820': 2,
#          '3839': 1,
#          '7609': 2,
#          '2316': 1,
#          '417': 12,
#          '5420': 5,
#          '812b': 1,
#          '1545': 1,
#          '2791': 1,
#          '513': 13,
#          '8323': 1,
#          '81': 2,
#          '1765': 1,
#          '2410': 3,
#          '1303': 4,
#          '620': 8,
#          '2904': 4,
#          '418 A': 1,
#          '2019': 7,
#          '749': 1,
#          '4016': 2,
#          '151': 10,
#          '1379': 1,
#          '1616': 1,
#          '4308': 3,
#          '1730': 1,
#          '511': 15,
#          '3015': 2,
#          '5708': 7,
#          '7720': 1,
#          '2797': 1,
#          '5730': 1,
#          '2321': 1,
#          '3406': 1,
#          '6806': 3,
#          '3021': 4,
#          '5757': 1,
#          '3837': 1,
#          '160': 2,
#          '1239': 2,
#          '3033': 1,
#          '1799': 1,
#          '7433': 1,
#          '3902': 2,
#          '5433': 2,
#          '3106': 2,
#          '1106': 6,
#          '343': 2,
#          '5026': 1,
#          '1918': 1,
#          '6116': 1,
#          '1740': 2,
#          '995': 1,
#          '6102': 1,
#          '6602-1': 1,
#          '2502': 5,
#          '734 A': 1,
#          '4093': 1,
#          '8816': 1,
#          '1910': 3,
#          '4509': 14,
#          '101 E. Morgan St': 1,
#          '8417': 1,
#          '132': 10,
#          '5116': 4,
#          '4125': 5,
#          '2642': 1,
#          '5712': 4,
#          '2106': 12,
#          '6260-102': 1,
#          '1110': 3,
#          '718': 2,
#          '5403': 1,
#          '2763': 1,
#          '4304': 4,
#          '5734': 2,
#          '1306': 2,
#          '6820': 1,
#          '982': 1,
#          '2324': 2,
#          '4117': 5,
#          '2439': 1,
#          '7301 Kit Creek Road': 1,
#          '682': 4,
#          '852': 1,
#          '2130': 2,
#          '8833': 1,
#          '1317': 5,
#          '1237': 1,
#          '3901': 2,
#          '708': 14,
#          '5223': 4,
#          '923': 2,
#          '7000': 3,
#          '263': 1,
#          '2205': 11,
#          '344': 3,
#          '8512': 5,
#          '5400': 12,
#          '203': 78,
#          '1114': 4,
#          '2531': 1,
#          '231,233,235,237': 1,
#          '2127': 4,
#          '1450': 1,
#          '1501': 5,
#          '159': 1,
#          '6010': 1,
#          '5476': 1,
#          '4619': 2,
#          '6705': 1,
#          '7017': 2,
#          '4727': 2,
#          '7020': 3,
#          '5275': 2,
#          '5030': 2,
#          '609a': 1,
#          '2310': 6,
#          '2304': 3,
#          '4104': 4,
#          '1320': 3,
#          '4723': 2,
#          '4122': 2,
#          '371': 2,
#          '1705': 4,
#          '1429': 2,
#          '8322': 1,
#          '204': 76,
#          '6824': 2,
#          '5744': 3,
#          '5004': 8,
#          '1109': 11,
#          '790': 1,
#          '533': 1,
#          '5615': 1,
#          '2031': 3,
#          '957': 1,
#          '1329': 1,
#          '4832': 3,
#          '2128': 6,
#          '1032': 1,
#          '336': 5,
#          '2232': 3,
#          '429': 3,
#          '4900': 5,
#          '104jj': 1,
#          '4805': 7,
#          '1005': 17,
#          '8011': 1,
#          '4302': 2,
#          '4603': 4,
#          '527': 1,
#          '1003': 7,
#          '2060': 1,
#          '2716': 3,
#          '1728': 1,
#          '2185': 1,
#          '258': 1,
#          '2210': 6,
#          '644': 2,
#          '1612': 1,
#          '7900': 1,
#          '3909': 1,
#          '421': 11,
#          '7': 4,
#          '4157': 1,
#          '509': 23,
#          '208': 67,
#          '491': 1,
#          '4301': 5,
#          '1010': 8,
#          '5117': 4,
#          '1020a': 1,
#          '3605': 2,
#          '4623': 1,
#          '2313': 4,
#          '4401': 8,
#          '3047': 1,
#          '5733': 1,
#          '9804': 1,
#          '3582': 1,
#          '731': 2,
#          '5472': 2,
#          '153': 2,
#          '6286-108': 1,
#          '145': 5,
#          '1130': 2,
#          '728': 8,
#          '179': 1,
#          '920': 6,
#          '1845': 1,
#          '347': 3,
#          '3441': 1,
#          '6656': 1,
#          '1903': 8,
#          '3457': 1,
#          '4137': 2,
#          '5743': 1,
#          '2851': 1,
#          '5318': 2,
#          '5619': 1,
#          '4132': 1,
#          '248': 2,
#          '3613': 2,
#          '5023': 1,
#          '3500': 5,
#          '6106': 1,
#          '134': 8,
#          '1073': 1,
#          '8543': 1,
#          '5022': 3,
#          '4618': 3,
#          '418 B': 1,
#          '150': 8,
#          '7153': 1,
#          '500-506': 1,
#          '3300': 3,
#          '3803': 1,
#          '2703': 2,
#          '978': 1,
#          '3421': 2,
#          '7620': 2,
#          '4901': 4,
#          '1059': 1,
#          '104d': 1,
#          '224': 13,
#          '4513': 11,
#          '112a': 1,
#          '12700': 1,
#          '2440': 1,
#          '2004': 15,
#          '3800': 1,
#          '152': 3,
#          '2126': 4,
#          '542': 1,
#          '8302': 1,
#          '1708': 2,
#          '2516': 2,
#          '1541': 1,
#          '8516': 4,
#          '2800': 6,
#          '2211': 6,
#          '251': 3,
#          '4739': 1,
#          '6118': 1,
#          '286': 1,
#          '4616': 8,
#          '715': 6,
#          '5000': 8,
#          '4041': 1,
#          '1713': 2,
#          '552': 1,
#          '3510': 2,
#          '5738': 2,
#          '5041': 4,
#          '5909': 1,
#          '5445': 1,
#          '453': 1,
#          '7610': 1,
#          '4929': 1,
#          '330': 6,
#          '814a': 1,
#          '900': 18,
#          '5320': 4,
#          '7008': 2,
#          '1245': 3,
#          '1118': 3,
#          '5618': 2,
#          '6600': 1,
#          '2600': 8,
#          '8537': 1,
#          '4': 1,
#          '4500': 16,
#          '9650': 1,
#          '311 A': 1,
#          '2134': 2,
#          '1304': 6,
#          '4029': 2,
#          '2012': 16,
#          '4040': 1,
#          '2418': 1,
#          '1022': 2,
#          '3023': 1,
#          '4202': 1,
#          '254': 2,
#          '3411': 1,
#          '2025': 6,
#          '4107': 1,
#          '6812': 1,
#          '8520': 3,
#          '991': 3,
#          '2625': 4,
#          '4420': 4,
#          '525': 3,
#          '5409': 8,
#          '916': 2,
#          '1104': 13,
#          '4400': 5,
#          '8115': 3,
#          '5525': 3,
#          '2808': 5,
#          '5319': 2,
#          '311': 33,
#          '3675': 1,
#          '1707': 3,
#          '7129': 2,
#          '4910': 3,
#          '2605': 7,
#          '1611': 1,
#          '954': 1,
#          '2916': 1,
#          '167': 1,
#          '2601': 6,
#          '1403': 5,
#          '2701': 4,
#          '604': 24,
#          '2909': 3,
#          '2708': 6,
#          '5512': 5,
#          '6274-106': 1,
#          '4607': 2,
#          '3570': 1,
#          '2458': 1,
#          '776': 1,
#          '5429': 4,
#          '1516': 1,
#          '1351': 1,
#          '1506': 2,
#          '7025-6': 1,
#          '970': 1,
#          '3914': 1,
#          '6660': 1,
#          '1817': 3,
#          '2854': 1,
#          '3609': 2,
#          '623': 2,
#          '234': 7,
#          '7830': 1,
#          '1277': 1,
#          '844': 1,
#          '1026': 1,
#          '4415': 1,
#          '4825': 4,
#          '4031': 1,
#          '3224': 1,
#          '272': 1,
#          '3801': 1,
#          '2707': 1,
#          'Suite 101': 1,
#          '5715': 3,
#          '1275': 1,
#          '5444': 1,
#          '3304': 1,
#          '4023': 1,
#          '5313': 10,
#          '213': 35,
#          '5750': 2,
#          '156': 3,
#          '2400': 7,
#          '360': 2,
#          '1498': 1,
#          '1943': 1,
#          '861': 3,
#          '9601': 1,
#          '3301': 2,
#          '309 B': 2,
#          '2002': 13,
#          '3113': 3,
#          '3117': 2,
#          '2712': 3,
#          '4731': 1,
#          '951': 3,
#          '4013': 1,
#          '5301': 7,
#          '7429': 1,
#          '2630': 1,
#          '363': 1,
#          '4508': 12,
#          '4002': 1,
#          '10511': 1,
#          '1108': 13,
#          '4405': 8,
#          '4421': 2,
#          '1929': 1,
#          '1629': 1,
#          '5328': 4,
#          '3001': 4,
#          '3114': 1,
#          '5824': 1,
#          '4712': 8,
#          '7125': 2,
#          '950': 1,
#          '5804': 5,
#          '2325': 2,
#          '5265': 1,
#          '2913': 2,
#          '1307': 7,
#          '8404': 2,
#          '541': 2,
#          '2008': 16,
#          '1039': 2,
#          '340': 3,
#          '6120': 2,
#          '3007': 3,
#          '4802': 6,
#          '6206': 1,
#          '3206': 1,
#          '5214': 1,
#          '1313': 7,
#          '7436': 2,
#          '2245': 1,
#          '1809': 9,
#          '304': 45,
#          '6216': 1,
#          '1423 E Club Blvd': 1,
#          '4907': 4,
#          '5735': 1,
#          '8200-1002': 1,
#          '5716': 7,
#          '6590-100': 1,
#          '5072': 1,
#          '5047': 1,
#          '1341': 1,
#          '1373': 1,
#          '1540': 1,
#          '4706': 5,
#          '4419': 1,
#          '1856': 1,
#          '2777': 1,
#          '1082': 1,
#          '725': 6,
#          '808': 13,
#          '904': 9,
#          '120': 42,
#          '142': 6,
#          '1308': 6,
#          '5005': 10,
#          '2308': 5,
#          '2125': 5,
#          '4221': 1,
#          '5': 4,
#          '239': 1,
#          '506 A; 506 B': 1,
#          '33': 1,
#          '6450': 2,
#          '809': 10,
#          '4520': 6,
#          '214': 34,
#          '2755': 1,
#          '721': 12,
#          '2115': 7,
#          '331': 4,
#          '8141': 1,
#          '4224': 2,
#          '351': 4,
#          '2136': 2,
#          '1024': 3,
#          '2436': 1,
#          '8309': 1,
#          '4309': 4,
#          '5129': 1,
#          ...})

# %%
amenities = audit(map_file,'amenity')

# %%
Counter(amenities).most_common()
# Out:
# [('parking', 1884),
#  ('place_of_worship', 535),
#  ('bicycle_parking', 522),
#  ('restaurant', 502),
#  ('fast_food', 253),
#  ('school', 221),
#  ('fuel', 202),
#  ('bench', 127),
#  ('bank', 111),
#  ('swimming_pool', 104),
#  ('cafe', 94),
#  ('waste_basket', 92),
#  ('toilets', 85),
#  ('atm', 76),
#  ('pharmacy', 71),
#  ('vending_machine', 65),
#  ('bar', 57),
#  ('pub', 47),
#  ('fountain', 47),
#  ('waste_disposal', 46),
#  ('recycling', 46),
#  ('post_box', 45),
#  ('fire_station', 43),
#  ('shelter', 43),
#  ('dentist', 43),
#  ('drinking_water', 39),
#  ('library', 39),
#  ('parking_entrance', 37),
#  ('post_office', 35),
#  ('doctors', 30),
#  ('hospital', 27),
#  ('college', 26),
#  ('theatre', 26),
#  ('car_wash', 24),
#  ('grave_yard', 22),
#  ('bbq', 18),
#  ('kindergarten', 17),
#  ('public_building', 16),
#  ('clinic', 15),
#  ('police', 14),
#  ('cinema', 14),
#  ('car_rental', 13),
#  ('university', 13),
#  ('veterinary', 12),
#  ('childcare', 11),
#  ('arts_centre', 11),
#  ('community_centre', 9),
#  ('bus_station', 9),
#  ('marketplace', 7),
#  ('courthouse', 7),
#  ('charging_station', 7),
#  ('telephone', 6),
#  ('ice_cream', 6),
#  ('animal_boarding', 6),
#  ('nightclub', 5),
#  ('retirement_home', 5),
#  ('taxi', 4),
#  ('training', 4),
#  ('spa', 4),
#  ('bicycle_repair_station', 4),
#  ('social_facility', 4),
#  ('tutor', 4),
#  ('storage', 3),
#  ('massage', 3),
#  ('clock', 3),
#  ('picnic_table', 3),
#  ('studio', 3),
#  ('townhall', 3),
#  ('prison', 3),
#  ('kindergarten;childcare', 2),
#  ('funeral_directors', 2),
#  ('truck_rental', 2),
#  ('medical', 2),
#  ('compressed_air', 2),
#  ('gazebo', 2),
#  ('social_centre', 2),
#  ('music_school', 2),
#  ('food_court', 2),
#  ('shop', 1),
#  ('vacuum', 1),
#  ('music_venue', 1),
#  ('animal_shelter', 1),
#  ('tutoring', 1),
#  ('massage_chair', 1),
#  ('money_transfer', 1),
#  ('blood_donation', 1),
#  ('audiologist', 1),
#  ('military_recruiting', 1),
#  ('coin_cashing_machine', 1),
#  ('garages', 1),
#  ('dojo', 1),
#  ('information', 1),
#  ('rental', 1),
#  ('bail_bonds', 1),
#  ('car_vacuum', 1),
#  ('reverse_vending_machine', 1),
#  ('biergarten', 1),
#  ('nursing_home', 1)]

# %%
states = audit(map_file,'addr:state')

# %%
state_count = Counter(states)

# %%
state_count
# Out:
# Counter({'NC': 4267, 'NY': 1, 'North Carolina': 296, 'nc': 2})

# %% [markdown]
# ___

# %% [markdown]
# ### Data Cleaning

# %%
def clean_city(city):

    expected = ['Apex','Carrboro','Cary', 'Chapel Hill', 'Durham', 'Morrisville', 'Raleigh', 'Wake Forest']
    
    mapping = {
        'Chapel Hill, NC': 'Chapel Hill',
        'Ra': 'Raleigh',
        'Research Triangle Park': 'Durham'
    }
    if city not in expected:
        city = mapping.get(city, city) #if city is not in mapping, city = city.
    #Convert to title case               
    return city.title()

# %%
def clean_street(street):
    street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
    
    #These are street_type values that we'd expect
    expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons",
           "Circle","Extension","Fork","Highway","Terrace", "Way"]

    #Created this list through auditing of the current values in the data
    street_type_mapping = { "St": "Street",
            "St.": "Street",
            "Rd." : "Road",
            "Ave" : "Avenue",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "CIrcle": "Circle",
            "Cir": "Circle",
            "Ct" : "Court",
            "Dr" : "Drive",
           "Ext" : "Extension",
           "Ln" : "Lane",
           "Loop": "Loop",
           "Pkwy": "Parkway",
           "Pky": "Parkway",
           "Pl": "Place",
           "PI": "Place",
           "Rd": "Road",
           "Rd.": "Road",
           "ST": "Street",
           "St": "Street",
           "St,": "Street"
            }
    
    m = street_type_re.search(street)
    
    if m:
        street_type = m.group()
        if street_type not in expected:
            #Use the replacement from the mapping if it exists.
            replacement = street_type_mapping.get(m.group(),0)
            if replacement:
                street = street_type_re.sub(replacement, street) 
                
    #Clean up street directions                   
    street_direction_re = re.compile(r'^[S W|SW|S E|SE|N W|NW|N E|NE|N|E|W|S]\.?\s+', re.IGNORECASE)

    street_direction_mapping = {"E.": "East ",
                           "E": "East ",
                           "W": "West ",
                           "W.": "West ",
                           "S": "South ",
                           "S.": "South ",
                           "N": "North ",
                           "N.": "North "}

    m = street_direction_re.search(street)

    if m:
        sd = m.group()
        replacement = street_direction_mapping.get(sd.strip(),0)
        if replacement:
            street = street_direction_re.sub(replacement,street)
                
    return street.title()

# %%
def clean_zip(zip_code):    
    #Parse zip into components 
    #Compare against gold standard list from postal service
    #Flag zips that are too short or too long (length != 5)
    return zip_code

# %%
def clean_address(address_dict):
    #Fix street types
    if 'street' in address_dict:
        address_dict['street'] = clean_street(address_dict['street'])
    if 'city' in address_dict:
        address_dict['city'] = clean_city(address_dict['city'])
    if 'postcode' in address_dict:
        address_dict['postcode'] = clean_zip(address_dict['postcode'])
    #All address records should have a state, and the state should be NC
    address_dict['state'] = 'NC'        
    
    return address_dict

# %% [markdown]
# ___

# %% [markdown]
# ### Data Processing
#
# ##### From leson 6 - shape element

# %%
def shape_element(element):
    
    CREATED = [ "version", "changeset", "timestamp", "user", "uid"]
    POS = ['lon', 'lat']
    problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
    
    prob_list = []
    elem = {}
    created_dict = {}
    nd_list = []
    pos_array = []
    address_dict = {}
    
    #process only node and way tags
    if element.tag == 'node' or element.tag == 'way':
        #include the element type
        elem['type'] = element.tag
        for x in element.attrib:
            #attributes in the CREATED array should be added under a 
            #key called 'created'
            if x  in CREATED:
                created_dict[x] = element.attrib[x]
            #attributes that are not in CREATED or POS should be
            #turned into regular key/value pairs
            elif x not in POS:
                elem[x] = element.attrib[x]
            #attributes for longitude and lattitude should be 
            #added to a pos array
        try:
            pos_array = [float(element.attrib['lat']),
                float(element.attrib['lon'])]
        except KeyError:
            pass
        #For 'way' specifically, <nd ref... elements should be
        #turned into 'node_refs': [...]
        if element.tag == 'way':
            for nd in element.iter('nd'):
                nd_list.append(nd.attrib['ref'])
            if len(nd_list) > 0:
                elem['node_refs'] = nd_list
        for tag in element.iter('tag'):
            #if tag 'k' value contains problematic characters, ignore it
            if problemchars.search(tag.attrib['k']):
                break
            #work on address dictionary
            if tag.attrib['k'].startswith('addr:'):
                pieces = tag.attrib['k'].split(':')
                if pieces[1] == 'street' and len(pieces) != 2:
                    break
                #if tag value 'k' starts with 'addr:' and doesn't have
                #a second ':' after street, add it to address dictionary
                address_dict[':'.join(pieces[1:])] = tag.attrib['v'] 
            else:
                #title case all elements
                elem[tag.attrib['k']] = tag.attrib['v'].title()
        if len(created_dict) > 0:
            elem['created'] = created_dict
        if len(pos_array) > 0:
            elem['pos'] = pos_array
        if len(address_dict) > 0:
            elem['address'] = clean_address(address_dict)
        return elem
    else:
        return None

def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %%
data = process_map(map_file, False)

# %%
data[0]
# Out:
# {'_id': ObjectId('5679402901cc623e537407db'),
#  'created': {'changeset': '7525913',
#   'timestamp': '2011-03-11T18:03:13Z',
#   'uid': '38487',
#   'user': 'jumbanho',
#   'version': '4'},
#  'id': '21592692',
#  'pos': [35.9746754, -78.9086172],
#  'type': 'node'}

# %% [markdown]
# ___

# %% [markdown]
# ### Import to MongoDB
# Also can do this on the command line using the `mongoimport` command
#
# >mongoimport -db dbname -c collectionname --file input-file.json

# %%
client = MongoClient('localhost:27017')
db = client.OSM

# %%
db.Raleigh.find().count()
# Out:
# 0

# %%
db.Raleigh.delete_many({})

# %%
db.Raleigh.insert_many(data)

# %%
db.Raleigh.find().count()
# Out:
# 2476726

# %%
len(data)
# Out:
# 2476726

# %%
db.Raleigh.find_one()
# Out:
# {'_id': ObjectId('5679402901cc623e537407db'),
#  'created': {'changeset': '7525913',
#   'timestamp': '2011-03-11T18:03:13Z',
#   'uid': '38487',
#   'user': 'jumbanho',
#   'version': '4'},
#  'id': '21592692',
#  'pos': [35.9746754, -78.9086172],
#  'type': 'node'}

# %%
db.Raleigh.find({"type":"node"}).count()
# Out:
# 2252656

# %%
db.Raleigh.find({"type":"way"}).count()
# Out:
# 224062

# %%
db.Raleigh.find({"type":"sewage"}).count()
# Out:
# 3

# %%
len(db.Raleigh.distinct("created.user"))
# Out:
# 716

# %%
db.Raleigh.aggregate([{"$match":{"type":{"$exists":1}}},])

# %%
pipeline = [{"$match":{"type":{"$exists":1}}}, {"$group":{"_id":"$type",
"count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":10}]

list(db.Raleigh.aggregate(pipeline))
# Out:
# [{'_id': 'node', 'count': 2252656},
#  {'_id': 'way', 'count': 224062},
#  {'_id': 'sewage', 'count': 3},
#  {'_id': 'water', 'count': 1},
#  {'_id': 'route', 'count': 1},
#  {'_id': 'video', 'count': 1},
#  {'_id': 'public', 'count': 1},
#  {'_id': 'audio', 'count': 1}]

# %% [markdown]
# ##### Get list of ammenities

# %%
pipeline = [{"$match":{"amenity":{"$exists":1}}}, {"$group":{"_id":"$amenity",
"count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":10}]

print (list(db.Raleigh.aggregate(pipeline)))
# Out:
# [{'_id': 'parking', 'count': 1925}, {'_id': 'place_of_worship', 'count': 544}, {'_id': 'bicycle_parking', 'count': 526}, {'_id': 'restaurant', 'count': 510}, {'_id': 'fast_food', 'count': 253}, {'_id': 'school', 'count': 226}, {'_id': 'fuel', 'count': 204}, {'_id': 'bench', 'count': 130}, {'_id': 'bank', 'count': 113}, {'_id': 'swimming_pool', 'count': 108}]

# %%
list(db.Raleigh.aggregate([{"$match":{"type":{"$exists":1}}}, {"$group":{"_id":"$type",
"count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":10}])
)
# Out:
# [{'_id': 'node', 'count': 2252656},
#  {'_id': 'way', 'count': 224062},
#  {'_id': 'sewage', 'count': 3},
#  {'_id': 'water', 'count': 1},
#  {'_id': 'route', 'count': 1},
#  {'_id': 'video', 'count': 1},
#  {'_id': 'public', 'count': 1},
#  {'_id': 'audio', 'count': 1}]

# %% [markdown]
# ___

# %% [markdown]
# ### Create a sample of the osm file
#
# Code is from instructor notes of of project submission instructions
#
# Had to modify for python 3: wrapped the strings to be written to the OSM file in str.encode() in order to get the bytestring representation.
#
# Also changed to pull every 50th top level element so that the file size would be small enough.  (Master file is about 450MB)

# %%
SAMPLE_FILE = "sample.osm"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write(str.encode('<?xml version="1.0" encoding="UTF-8"?>\n'))
    output.write(str.encode('<osm>\n  '))

    # Write every 50th top level element
    for i, element in enumerate(get_element(map_file)):
        if i % 50 == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write(str.encode('</osm>'))
